# %%
#importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
ords_prods_merge = pd.read_pickle(r'/Users/nayeraibrahim/Documents/CF assignments/Python/27-10-2020 Instacart Basket Analysis/02 Data/Prepared Data/ orders_products_merged.pkl')

# %%
#first million entries - subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.head(10)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0  2539329.0      1.0    prior           1.0        2.0                8.0
# 1  2398795.0      1.0    prior           2.0        3.0                7.0
# 2   473747.0      1.0    prior           3.0        3.0               12.0
# 3  2254736.0      1.0    prior           4.0        4.0                7.0
# 4   431534.0      1.0    prior           5.0        4.0               15.0
# 5  3367565.0      1.0    prior           6.0        2.0                7.0
# 6   550135.0      1.0    prior           7.0        1.0                9.0
# 7  3108588.0      1.0    prior           8.0        1.0               14.0
# 8  2295261.0      1.0    prior           9.0        1.0               16.0
# 9  2550362.0      1.0    prior          10.0        4.0                8.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                1.0        0.0   both
# 1                    15.0         196                1.0        1.0   both
# 2                    21.0         196                1.0        1.0   both
# 3                    29.0         196                1.0        1.0   both
# 4                    28.0         196                1.0        1.0   both
# 5                    19.0         196                1.0        1.0   both
# 6                    20.0         196                1.0        1.0   both
# 7                    14.0         196                2.0        1.0   both
# 8                     0.0         196                4.0        1.0   both
# 9                    30.0         196                1.0        1.0   both
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices _merge2
# 0       195.0         Soda      77.0            7.0     9.0    both
# 1       195.0         Soda      77.0            7.0     9.0    both
# 2       195.0         Soda      77.0            7.0     9.0    both
# 3       195.0         Soda      77.0            7.0     9.0    both
# 4       195.0         Soda      77.0            7.0     9.0    both
# 5       195.0         Soda      77.0            7.0     9.0    both
# 6       195.0         Soda      77.0            7.0     9.0    both
# 7       195.0         Soda      77.0            7.0     9.0    both
# 8       195.0         Soda      77.0            7.0     9.0    both
# 9       195.0         Soda      77.0            7.0     9.0    both

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4.0              18.825780
# 7.0              17.472355
# 13.0             17.993423
# 14.0             19.246334
# 16.0             19.463012
# 17.0             11.294069
# 19.0             19.305237
# 20.0             17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4.0     18.825780
# 7.0     17.472355
# 13.0    17.993423
# 14.0    19.246334
# 16.0    19.463012
# 17.0    11.294069
# 19.0    19.305237
# 20.0    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean  min   max
# department_id
# 4.0              18.825780  1.0  99.0
# 7.0              17.472355  1.0  99.0
# 13.0             17.993423  1.0  99.0
# 14.0             19.246334  1.0  99.0
# 16.0             19.463012  1.0  99.0
# 17.0             11.294069  1.0  98.0
# 19.0             19.305237  1.0  99.0
# 20.0             17.599636  1.0  99.0

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#      order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329.0      1.0    prior           1.0        2.0                8.0
# 1   2398795.0      1.0    prior           2.0        3.0                7.0
# 2    473747.0      1.0    prior           3.0        3.0               12.0
# 3   2254736.0      1.0    prior           4.0        4.0                7.0
# 4    431534.0      1.0    prior           5.0        4.0               15.0
# 5   3367565.0      1.0    prior           6.0        2.0                7.0
# 6    550135.0      1.0    prior           7.0        1.0                9.0
# 7   3108588.0      1.0    prior           8.0        1.0               14.0
# 8   2295261.0      1.0    prior           9.0        1.0               16.0
# 9   2550362.0      1.0    prior          10.0        4.0                8.0
# 10  2968173.0     15.0    prior          15.0        1.0                9.0
# 11  1870022.0     15.0    prior          17.0        2.0               16.0
# 12  1911383.0     15.0    prior          18.0        2.0               11.0
# 13  2715276.0     15.0    prior          21.0        1.0                9.0
# 14   487368.0     15.0    prior          22.0        1.0               10.0
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      NaN         196                1.0        0.0   both
# 1                     15.0         196                1.0        1.0   both
# 2                     21.0         196                1.0        1.0   both
# 3                     29.0         196                1.0        1.0   both
# 4                     28.0         196                1.0        1.0   both
# 5                     19.0         196                1.0        1.0   both
# 6                     20.0         196                1.0        1.0   both
# 7                     14.0         196                2.0        1.0   both
# 8                      0.0         196                4.0        1.0   both
# 9                     30.0         196                1.0        1.0   both
# 10                     7.0         196                2.0        0.0   both
# 11                     8.0         196                6.0        1.0   both
# 12                     7.0         196                1.0        1.0   both
# 13                     7.0         196                1.0        1.0   both
# 14                    14.0         196                1.0        1.0   both
#
#     Unnamed: 0 product_name  aisle_id  department_id  prices _merge2  \
# 0        195.0         Soda      77.0            7.0     9.0    both
# 1        195.0         Soda      77.0            7.0     9.0    both
# 2        195.0         Soda      77.0            7.0     9.0    both
# 3        195.0         Soda      77.0            7.0     9.0    both
# 4        195.0         Soda      77.0            7.0     9.0    both
# 5        195.0         Soda      77.0            7.0     9.0    both
# 6        195.0         Soda      77.0            7.0     9.0    both
# 7        195.0         Soda      77.0            7.0     9.0    both
# 8        195.0         Soda      77.0            7.0     9.0    both
# 9        195.0         Soda      77.0            7.0     9.0    both
# 10       195.0         Soda      77.0            7.0     9.0    both
# 11       195.0         Soda      77.0            7.0     9.0    both
# 12       195.0         Soda      77.0            7.0     9.0    both
# 13       195.0         Soda      77.0            7.0     9.0    both
# 14       195.0         Soda      77.0            7.0     9.0    both
#
#     max_order
# 0        10.0
# 1        10.0
# 2        10.0
# 3        10.0
# 4        10.0
# 5        10.0
# 6        10.0
# 7        10.0
# 8        10.0
# 9        10.0
# 10       22.0
# 11       22.0
# 12       22.0
# 13       22.0
# 14       22.0

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#      order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329.0      1.0    prior           1.0        2.0                8.0
# 1   2398795.0      1.0    prior           2.0        3.0                7.0
# 2    473747.0      1.0    prior           3.0        3.0               12.0
# 3   2254736.0      1.0    prior           4.0        4.0                7.0
# 4    431534.0      1.0    prior           5.0        4.0               15.0
# 5   3367565.0      1.0    prior           6.0        2.0                7.0
# 6    550135.0      1.0    prior           7.0        1.0                9.0
# 7   3108588.0      1.0    prior           8.0        1.0               14.0
# 8   2295261.0      1.0    prior           9.0        1.0               16.0
# 9   2550362.0      1.0    prior          10.0        4.0                8.0
# 10  2968173.0     15.0    prior          15.0        1.0                9.0
# 11  1870022.0     15.0    prior          17.0        2.0               16.0
# 12  1911383.0     15.0    prior          18.0        2.0               11.0
# 13  2715276.0     15.0    prior          21.0        1.0                9.0
# 14   487368.0     15.0    prior          22.0        1.0               10.0
# 15  2293453.0     19.0    prior           2.0        5.0               14.0
# 16  1973799.0     19.0    prior           5.0        6.0               12.0
# 17   532817.0     19.0    prior           7.0        4.0               17.0
# 18  1573906.0     21.0    prior          10.0        3.0               10.0
# 19  1593000.0     31.0    prior          10.0        3.0                8.0
# 20  2231262.0     31.0    prior          17.0        3.0               11.0
# 21  2580647.0     43.0    prior           6.0        4.0               16.0
# 22  2187180.0     43.0    prior           9.0        4.0               12.0
# 23  2497897.0     52.0    prior           1.0        1.0                9.0
# 24  1318871.0     52.0    prior           2.0        1.0               10.0
# 25  1261384.0     52.0    prior           3.0        1.0               10.0
# 26   580568.0     52.0    prior           5.0        2.0               10.0
# 27  2428073.0     52.0    prior           7.0        2.0                7.0
# 28   342306.0     52.0    prior           9.0        1.0               11.0
# 29  1520353.0     52.0    prior          10.0        2.0               10.0
# 30  2542086.0     52.0    prior          11.0        2.0                9.0
# 31   944694.0     52.0    prior          12.0        1.0               16.0
# 32  1268191.0     52.0    prior          15.0        2.0               11.0
# 33  1122089.0     52.0    prior          17.0        2.0               10.0
# 34  1498922.0     52.0    prior          18.0        2.0               10.0
# 35   180919.0     52.0    prior          19.0        3.0                8.0
# 36  2695875.0     52.0    prior          21.0        5.0               10.0
# 37  3205960.0     67.0    prior           1.0        3.0               11.0
# 38   970922.0     67.0    prior           2.0        1.0               15.0
# 39   596585.0     67.0    prior           3.0        1.0               13.0
# 40  2037087.0     67.0    prior           4.0        2.0                9.0
# 41  2474111.0     67.0    prior           5.0        3.0               14.0
# 42  1568481.0     67.0    prior           6.0        3.0               12.0
# 43  2048527.0     67.0    prior           8.0        2.0               11.0
# 44  2389031.0     67.0    prior           9.0        2.0               14.0
# 45  2378562.0     67.0    prior          10.0        1.0               10.0
# 46  1515698.0     67.0    prior          11.0        1.0               11.0
# 47  1928050.0     67.0    prior          12.0        2.0               12.0
# 48  1949274.0     67.0    prior          13.0        1.0               10.0
# 49   551869.0     67.0    prior          14.0        1.0                9.0
# 50   768572.0     67.0    prior          16.0        4.0               10.0
# 51   150528.0     67.0    prior          18.0        5.0               16.0
# 52    29758.0     67.0    prior          19.0        0.0               14.0
# 53  1558976.0     67.0    prior          21.0        1.0                9.0
# 54   863974.0     67.0    prior          22.0        1.0               11.0
# 55  2308399.0     67.0    prior          23.0        1.0               14.0
# 56  2759128.0     81.0    prior           3.0        1.0                9.0
# 57  1812985.0     81.0    prior           5.0        2.0               20.0
# 58  1889835.0     82.0    prior           1.0        3.0               15.0
# 59   499460.0     82.0    prior           3.0        5.0               10.0
# 60  2728456.0     82.0    prior           4.0        0.0               11.0
# 61  2653743.0     82.0    prior           6.0        4.0                9.0
# 62  1358880.0     82.0    prior           9.0        1.0               10.0
# 63   343588.0     82.0    prior          10.0        2.0               11.0
# 64  3034663.0     82.0    prior          15.0        2.0               11.0
# 65   147262.0     82.0    prior          18.0        1.0               13.0
# 66  3144004.0     82.0    prior          19.0        2.0               15.0
# 67  2126069.0     98.0    prior           3.0        0.0                9.0
# 68  2210120.0     98.0    prior           7.0        5.0               14.0
# 69   681011.0     98.0    prior           9.0        3.0                9.0
# 70  2846344.0     98.0    prior          11.0        4.0               13.0
# 71   747431.0     98.0    prior          12.0        6.0               13.0
# 72  2383054.0     98.0    prior          13.0        4.0               11.0
# 73  1993729.0     98.0    prior          14.0        5.0                8.0
# 74  1403849.0    109.0    prior           3.0        3.0               17.0
# 75   520620.0    120.0    prior           1.0        3.0               11.0
# 76  3273029.0    120.0    prior           3.0        2.0                8.0
# 77  1861943.0    185.0    prior           2.0        1.0               12.0
# 78  2040988.0    195.0    prior           1.0        1.0               14.0
# 79  1680569.0    195.0    prior           8.0        1.0                9.0
# 80   276171.0    195.0    prior          19.0        5.0               11.0
# 81  2744976.0    195.0    prior          22.0        5.0               10.0
# 82  2781919.0    195.0    prior          25.0        1.0               14.0
# 83  1738718.0    195.0    prior          31.0        2.0                8.0
# 84  3058369.0    195.0    prior          34.0        3.0               10.0
# 85  1485596.0    195.0    prior          37.0        2.0               15.0
# 86   417035.0    195.0    prior          40.0        3.0               16.0
# 87  1615297.0    195.0    prior          47.0        5.0               10.0
# 88  1765587.0    195.0    prior          52.0        3.0               12.0
# 89   745908.0    195.0    prior          57.0        4.0               11.0
# 90  2505656.0    222.0    prior          17.0        2.0               12.0
# 91  3268370.0    222.0    prior          38.0        5.0               15.0
# 92  2016711.0    290.0    prior           9.0        5.0               19.0
# 93  2706088.0    290.0    prior          28.0        6.0               10.0
# 94  1952286.0    331.0    prior           6.0        5.0               16.0
# 95  3226575.0    360.0    prior           1.0        5.0               12.0
# 96  1469869.0    377.0    prior           3.0        5.0               17.0
# 97  1927023.0    387.0    prior           2.0        4.0               10.0
# 98   858092.0    420.0    prior           4.0        1.0               19.0
# 99   119314.0    420.0    prior           5.0        3.0               19.0
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      NaN         196                1.0        0.0   both
# 1                     15.0         196                1.0        1.0   both
# 2                     21.0         196                1.0        1.0   both
# 3                     29.0         196                1.0        1.0   both
# 4                     28.0         196                1.0        1.0   both
# 5                     19.0         196                1.0        1.0   both
# 6                     20.0         196                1.0        1.0   both
# 7                     14.0         196                2.0        1.0   both
# 8                      0.0         196                4.0        1.0   both
# 9                     30.0         196                1.0        1.0   both
# 10                     7.0         196                2.0        0.0   both
# 11                     8.0         196                6.0        1.0   both
# 12                     7.0         196                1.0        1.0   both
# 13                     7.0         196                1.0        1.0   both
# 14                    14.0         196                1.0        1.0   both
# 15                     6.0         196                3.0        0.0   both
# 16                     8.0         196               15.0        1.0   both
# 17                     6.0         196                1.0        1.0   both
# 18                     6.0         196                2.0        0.0   both
# 19                     7.0         196               17.0        0.0   both
# 20                     8.0         196               14.0        1.0   both
# 21                     4.0         196                9.0        0.0   both
# 22                     3.0         196                1.0        1.0   both
# 23                     NaN         196                4.0        0.0   both
# 24                     7.0         196                5.0        1.0   both
# 25                     7.0         196                3.0        1.0   both
# 26                     8.0         196                6.0        1.0   both
# 27                     8.0         196                5.0        1.0   both
# 28                     7.0         196                5.0        1.0   both
# 29                     8.0         196                4.0        1.0   both
# 30                     7.0         196                3.0        1.0   both
# 31                     6.0         196                7.0        1.0   both
# 32                     8.0         196                3.0        1.0   both
# 33                     6.0         196                4.0        1.0   both
# 34                    14.0         196                6.0        1.0   both
# 35                     8.0         196                4.0        1.0   both
# 36                    30.0         196                1.0        1.0   both
# 37                     NaN         196                1.0        0.0   both
# 38                     5.0         196                2.0        1.0   both
# 39                     7.0         196                2.0        1.0   both
# 40                     8.0         196                1.0        1.0   both
# 41                     8.0         196                2.0        1.0   both
# 42                     7.0         196                2.0        1.0   both
# 43                     7.0         196                1.0        1.0   both
# 44                     7.0         196                1.0        1.0   both
# 45                     6.0         196                1.0        1.0   both
# 46                     7.0         196                1.0        1.0   both
# 47                     8.0         196                1.0        1.0   both
# 48                     6.0         196                1.0        1.0   both
# 49                     7.0         196                1.0        1.0   both
# 50                     9.0         196                1.0        1.0   both
# 51                     4.0         196                1.0        1.0   both
# 52                     9.0         196                2.0        1.0   both
# 53                     5.0         196                2.0        1.0   both
# 54                    14.0         196                3.0        1.0   both
# 55                    14.0         196                1.0        1.0   both
# 56                    14.0         196                2.0        0.0   both
# 57                    30.0         196                1.0        1.0   both
# 58                     NaN         196                6.0        0.0   both
# 59                     5.0         196                2.0        1.0   both
# 60                    16.0         196                1.0        1.0   both
# 61                    13.0         196                5.0        1.0   both
# 62                    30.0         196                1.0        1.0   both
# 63                     1.0         196                1.0        1.0   both
# 64                    12.0         196                1.0        1.0   both
# 65                     7.0         196                1.0        1.0   both
# 66                     8.0         196                1.0        1.0   both
# 67                    25.0         196                7.0        0.0   both
# 68                     5.0         196                1.0        1.0   both
# 69                    30.0         196                1.0        1.0   both
# 70                    15.0         196                2.0        1.0   both
# 71                    30.0         196                4.0        1.0   both
# 72                    30.0         196                1.0        1.0   both
# 73                     8.0         196                2.0        1.0   both
# 74                     9.0         196                5.0        0.0   both
# 75                     NaN         196                2.0        0.0   both
# 76                    19.0         196                2.0        1.0   both
# 77                    25.0         196               10.0        0.0   both
# 78                     NaN         196                2.0        0.0   both
# 79                     4.0         196                2.0        1.0   both
# 80                     3.0         196                2.0        1.0   both
# 81                     7.0         196                2.0        1.0   both
# 82                     4.0         196                1.0        1.0   both
# 83                     4.0         196                2.0        1.0   both
# 84                     6.0         196                2.0        1.0   both
# 85                     0.0         196                2.0        1.0   both
# 86                     2.0         196                2.0        1.0   both
# 87                     2.0         196                2.0        1.0   both
# 88                     2.0         196                3.0        1.0   both
# 89                     3.0         196                3.0        1.0   both
# 90                     1.0         196                2.0        0.0   both
# 91                     1.0         196                6.0        1.0   both
# 92                     6.0         196                8.0        0.0   both
# 93                     7.0         196               16.0        1.0   both
# 94                    30.0         196                8.0        0.0   both
# 95                     NaN         196                1.0        0.0   both
# 96                     3.0         196                9.0        0.0   both
# 97                    22.0         196                3.0        0.0   both
# 98                    30.0         196                2.0        0.0   both
# 99                    16.0         196                2.0        1.0   both
#
#     Unnamed: 0 product_name  aisle_id  department_id  prices _merge2  \
# 0        195.0         Soda      77.0            7.0     9.0    both
# 1        195.0         Soda      77.0            7.0     9.0    both
# 2        195.0         Soda      77.0            7.0     9.0    both
# 3        195.0         Soda      77.0            7.0     9.0    both
# 4        195.0         Soda      77.0            7.0     9.0    both
# 5        195.0         Soda      77.0            7.0     9.0    both
# 6        195.0         Soda      77.0            7.0     9.0    both
# 7        195.0         Soda      77.0            7.0     9.0    both
# 8        195.0         Soda      77.0            7.0     9.0    both
# 9        195.0         Soda      77.0            7.0     9.0    both
# 10       195.0         Soda      77.0            7.0     9.0    both
# 11       195.0         Soda      77.0            7.0     9.0    both
# 12       195.0         Soda      77.0            7.0     9.0    both
# 13       195.0         Soda      77.0            7.0     9.0    both
# 14       195.0         Soda      77.0            7.0     9.0    both
# 15       195.0         Soda      77.0            7.0     9.0    both
# 16       195.0         Soda      77.0            7.0     9.0    both
# 17       195.0         Soda      77.0            7.0     9.0    both
# 18       195.0         Soda      77.0            7.0     9.0    both
# 19       195.0         Soda      77.0            7.0     9.0    both
# 20       195.0         Soda      77.0            7.0     9.0    both
# 21       195.0         Soda      77.0            7.0     9.0    both
# 22       195.0         Soda      77.0            7.0     9.0    both
# 23       195.0         Soda      77.0            7.0     9.0    both
# 24       195.0         Soda      77.0            7.0     9.0    both
# 25       195.0         Soda      77.0            7.0     9.0    both
# 26       195.0         Soda      77.0            7.0     9.0    both
# 27       195.0         Soda      77.0            7.0     9.0    both
# 28       195.0         Soda      77.0            7.0     9.0    both
# 29       195.0         Soda      77.0            7.0     9.0    both
# 30       195.0         Soda      77.0            7.0     9.0    both
# 31       195.0         Soda      77.0            7.0     9.0    both
# 32       195.0         Soda      77.0            7.0     9.0    both
# 33       195.0         Soda      77.0            7.0     9.0    both
# 34       195.0         Soda      77.0            7.0     9.0    both
# 35       195.0         Soda      77.0            7.0     9.0    both
# 36       195.0         Soda      77.0            7.0     9.0    both
# 37       195.0         Soda      77.0            7.0     9.0    both
# 38       195.0         Soda      77.0            7.0     9.0    both
# 39       195.0         Soda      77.0            7.0     9.0    both
# 40       195.0         Soda      77.0            7.0     9.0    both
# 41       195.0         Soda      77.0            7.0     9.0    both
# 42       195.0         Soda      77.0            7.0     9.0    both
# 43       195.0         Soda      77.0            7.0     9.0    both
# 44       195.0         Soda      77.0            7.0     9.0    both
# 45       195.0         Soda      77.0            7.0     9.0    both
# 46       195.0         Soda      77.0            7.0     9.0    both
# 47       195.0         Soda      77.0            7.0     9.0    both
# 48       195.0         Soda      77.0            7.0     9.0    both
# 49       195.0         Soda      77.0            7.0     9.0    both
# 50       195.0         Soda      77.0            7.0     9.0    both
# 51       195.0         Soda      77.0            7.0     9.0    both
# 52       195.0         Soda      77.0            7.0     9.0    both
# 53       195.0         Soda      77.0            7.0     9.0    both
# 54       195.0         Soda      77.0            7.0     9.0    both
# 55       195.0         Soda      77.0            7.0     9.0    both
# 56       195.0         Soda      77.0            7.0     9.0    both
# 57       195.0         Soda      77.0            7.0     9.0    both
# 58       195.0         Soda      77.0            7.0     9.0    both
# 59       195.0         Soda      77.0            7.0     9.0    both
# 60       195.0         Soda      77.0            7.0     9.0    both
# 61       195.0         Soda      77.0            7.0     9.0    both
# 62       195.0         Soda      77.0            7.0     9.0    both
# 63       195.0         Soda      77.0            7.0     9.0    both
# 64       195.0         Soda      77.0            7.0     9.0    both
# 65       195.0         Soda      77.0            7.0     9.0    both
# 66       195.0         Soda      77.0            7.0     9.0    both
# 67       195.0         Soda      77.0            7.0     9.0    both
# 68       195.0         Soda      77.0            7.0     9.0    both
# 69       195.0         Soda      77.0            7.0     9.0    both
# 70       195.0         Soda      77.0            7.0     9.0    both
# 71       195.0         Soda      77.0            7.0     9.0    both
# 72       195.0         Soda      77.0            7.0     9.0    both
# 73       195.0         Soda      77.0            7.0     9.0    both
# 74       195.0         Soda      77.0            7.0     9.0    both
# 75       195.0         Soda      77.0            7.0     9.0    both
# 76       195.0         Soda      77.0            7.0     9.0    both
# 77       195.0         Soda      77.0            7.0     9.0    both
# 78       195.0         Soda      77.0            7.0     9.0    both
# 79       195.0         Soda      77.0            7.0     9.0    both
# 80       195.0         Soda      77.0            7.0     9.0    both
# 81       195.0         Soda      77.0            7.0     9.0    both
# 82       195.0         Soda      77.0            7.0     9.0    both
# 83       195.0         Soda      77.0            7.0     9.0    both
# 84       195.0         Soda      77.0            7.0     9.0    both
# 85       195.0         Soda      77.0            7.0     9.0    both
# 86       195.0         Soda      77.0            7.0     9.0    both
# 87       195.0         Soda      77.0            7.0     9.0    both
# 88       195.0         Soda      77.0            7.0     9.0    both
# 89       195.0         Soda      77.0            7.0     9.0    both
# 90       195.0         Soda      77.0            7.0     9.0    both
# 91       195.0         Soda      77.0            7.0     9.0    both
# 92       195.0         Soda      77.0            7.0     9.0    both
# 93       195.0         Soda      77.0            7.0     9.0    both
# 94       195.0         Soda      77.0            7.0     9.0    both
# 95       195.0         Soda      77.0            7.0     9.0    both
# 96       195.0         Soda      77.0            7.0     9.0    both
# 97       195.0         Soda      77.0            7.0     9.0    both
# 98       195.0         Soda      77.0            7.0     9.0    both
# 99       195.0         Soda      77.0            7.0     9.0    both
#
#     max_order
# 0        10.0
# 1        10.0
# 2        10.0
# 3        10.0
# 4        10.0
# 5        10.0
# 6        10.0
# 7        10.0
# 8        10.0
# 9        10.0
# 10       22.0
# 11       22.0
# 12       22.0
# 13       22.0
# 14       22.0
# 15        9.0
# 16        9.0
# 17        9.0
# 18       33.0
# 19       20.0
# 20       20.0
# 21       11.0
# 22       11.0
# 23       27.0
# 24       27.0
# 25       27.0
# 26       27.0
# 27       27.0
# 28       27.0
# 29       27.0
# 30       27.0
# 31       27.0
# 32       27.0
# 33       27.0
# 34       27.0
# 35       27.0
# 36       27.0
# 37       24.0
# 38       24.0
# 39       24.0
# 40       24.0
# 41       24.0
# 42       24.0
# 43       24.0
# 44       24.0
# 45       24.0
# 46       24.0
# 47       24.0
# 48       24.0
# 49       24.0
# 50       24.0
# 51       24.0
# 52       24.0
# 53       24.0
# 54       24.0
# 55       24.0
# 56        7.0
# 57        7.0
# 58       19.0
# 59       19.0
# 60       19.0
# 61       19.0
# 62       19.0
# 63       19.0
# 64       19.0
# 65       19.0
# 66       19.0
# 67       14.0
# 68       14.0
# 69       14.0
# 70       14.0
# 71       14.0
# 72       14.0
# 73       14.0
# 74        6.0
# 75        3.0
# 76        3.0
# 77        6.0
# 78       58.0
# 79       58.0
# 80       58.0
# 81       58.0
# 82       58.0
# 83       58.0
# 84       58.0
# 85       58.0
# 86       58.0
# 87       58.0
# 88       58.0
# 89       58.0
# 90       70.0
# 91       70.0
# 92       51.0
# 93       51.0
# 94        8.0
# 95        3.0
# 96        3.0
# 97        8.0
# 98       22.0
# 99       22.0

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular customer    15892126
# Loyal customer      10294330
# New customer         6249785
# NaN                       11
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       1.0      New customer           1.0
# 1       1.0      New customer           2.0
# 2       1.0      New customer           3.0
# 3       1.0      New customer           4.0
# 4       1.0      New customer           5.0
# 5       1.0      New customer           6.0
# 6       1.0      New customer           7.0
# 7       1.0      New customer           8.0
# 8       1.0      New customer           9.0
# 9       1.0      New customer          10.0
# 10     15.0  Regular customer          15.0
# 11     15.0  Regular customer          17.0
# 12     15.0  Regular customer          18.0
# 13     15.0  Regular customer          21.0
# 14     15.0  Regular customer          22.0
# 15     19.0      New customer           2.0
# 16     19.0      New customer           5.0
# 17     19.0      New customer           7.0
# 18     21.0  Regular customer          10.0
# 19     31.0  Regular customer          10.0
# 20     31.0  Regular customer          17.0
# 21     43.0  Regular customer           6.0
# 22     43.0  Regular customer           9.0
# 23     52.0  Regular customer           1.0
# 24     52.0  Regular customer           2.0
# 25     52.0  Regular customer           3.0
# 26     52.0  Regular customer           5.0
# 27     52.0  Regular customer           7.0
# 28     52.0  Regular customer           9.0
# 29     52.0  Regular customer          10.0
# 30     52.0  Regular customer          11.0
# 31     52.0  Regular customer          12.0
# 32     52.0  Regular customer          15.0
# 33     52.0  Regular customer          17.0
# 34     52.0  Regular customer          18.0
# 35     52.0  Regular customer          19.0
# 36     52.0  Regular customer          21.0
# 37     67.0  Regular customer           1.0
# 38     67.0  Regular customer           2.0
# 39     67.0  Regular customer           3.0
# 40     67.0  Regular customer           4.0
# 41     67.0  Regular customer           5.0
# 42     67.0  Regular customer           6.0
# 43     67.0  Regular customer           8.0
# 44     67.0  Regular customer           9.0
# 45     67.0  Regular customer          10.0
# 46     67.0  Regular customer          11.0
# 47     67.0  Regular customer          12.0
# 48     67.0  Regular customer          13.0
# 49     67.0  Regular customer          14.0
# 50     67.0  Regular customer          16.0
# 51     67.0  Regular customer          18.0
# 52     67.0  Regular customer          19.0
# 53     67.0  Regular customer          21.0
# 54     67.0  Regular customer          22.0
# 55     67.0  Regular customer          23.0
# 56     81.0      New customer           3.0
# 57     81.0      New customer           5.0
# 58     82.0  Regular customer           1.0
# 59     82.0  Regular customer           3.0
