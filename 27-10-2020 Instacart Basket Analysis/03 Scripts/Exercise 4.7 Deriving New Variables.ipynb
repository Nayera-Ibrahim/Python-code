# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # importing file

# %%
ords_prods_merge = pd.read_pickle(r'/Users/nayeraibrahim/Documents/CF assignments/Python/27-10-2020 Instacart Basket Analysis/02 Data/Prepared Data/ orders_products_merged.pkl')

# %%
#picking first million rown to work with
df = ords_prods_merge[:1000000]
df.shape
# Out:
# (1000000, 17)

# %%
#define function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
#applying function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/9w/fhp8l0797mzfv0_yjbsv550w0000gn/T/ipykernel_98764/3677927974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid-range product     21862005
# Low-range product     10126369
# High-range product      417678
# NaN                      30200
# Name: price_range_loc, dtype: int64

# %%
result = []

for value in ords_prods_merge["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merge['busiest_day'] = result
ords_prods_merge['busiest_day']. value_counts(dropna = False)
# Out:
# Regularly busy    22438808
# Busiest day        6210030
# Least busy         3787414
# Name: busiest_day, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0  2539329.0      1.0    prior           1.0        2.0                8.0
# 1  2398795.0      1.0    prior           2.0        3.0                7.0
# 2   473747.0      1.0    prior           3.0        3.0               12.0
# 3  2254736.0      1.0    prior           4.0        4.0                7.0
# 4   431534.0      1.0    prior           5.0        4.0               15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                1.0        0.0   both
# 1                    15.0         196                1.0        1.0   both
# 2                    21.0         196                1.0        1.0   both
# 3                    29.0         196                1.0        1.0   both
# 4                    28.0         196                1.0        1.0   both
#
# ...

# %% [markdown]
# # Task

# %%
#2
result = []

for value in ords_prods_merge["order_dow"]:
  if value in (0,1):
    result.append("Busiest two days")
  elif value in (3,4):
    result.append("Least busy days")
  else:
    result.append("moderately busy")

# %%
result
# Out:
# ['moderately busy',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'moderately busy',
#  'Busiest two days',
#  'Busiest two days',
#  'Busiest two days',
#  'Least busy days',
#  'Busiest two days',
#  'moderately busy',
#  'moderately busy',
#  'Busiest two days',
#  'Busiest two days',
#  'moderately busy',
#  'moderately busy',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Busiest two days',
#  'Busiest two days',
#  'Busiest two days',
#  'moderately busy',
#  'moderately busy',
#  'Busiest two days',
#  'moderately busy',
#  'moderately busy',
#  'Busiest two days',
#  'moderately busy',
#  'moderately busy',
#  'moderately busy',
#  'Least busy days',
#  'moderately busy',
#  'Least busy days',
#  'Busiest two days',
#  'Busiest two days',
#  'moderately busy',
#  'Least busy days',
#  'Least busy days',
#  'moderately busy',
# ...

# %%
ords_prods_merge['busiest_days'] = result
ords_prods_merge['busiest_days']. value_counts(dropna = False)
# Out:
# moderately busy     12928289
# Busiest two days    11876207
# Least busy days      7631756
# Name: busiest_days, dtype: int64

# %%
#4
ords_prods_merge['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 10.0    2764578
# 11.0    2738749
# 14.0    2691713
# 15.0    2664685
# 13.0    2663449
# 12.0    2620979
# 16.0    2537617
# 9.0     2456821
# 17.0    2089577
# 8.0     1720055
# 18.0    1638020
# 19.0    1259463
# 20.0     977075
# 7.0      891979
# 21.0     796400
# 22.0     634765
# 23.0     402640
# 6.0      290803
# 0.0      218968
# 1.0      115793
# 5.0       88067
# 2.0       69437
# 4.0       53287
# 3.0       51321
# NaN          11
# Name: order_hour_of_day, dtype: int64

# %%
result = []

for value in ords_prods_merge["order_hour_of_day"]:
  if value in (10,11,14,15,13,12,16,9):
    result.append("most orders")
  elif value in (17,8,18,19,20,7,21,22):
    result.append("average orders")
  else:
    result.append("fewest orders")

# %%
ords_prods_merge['busiest_period_of_day'] = result
ords_prods_merge['busiest_period_of_day']. value_counts(dropna = False)
# Out:
# most orders       21138591
# average orders    10007334
# fewest orders      1290327
# Name: busiest_period_of_day, dtype: int64

# %%
#7
ords_prods_merge.to_pickle(r'/Users/nayeraibrahim/Documents/CF assignments/Python/27-10-2020 Instacart Basket Analysis/02 Data/Prepared Data/orders_products_4_7.pkl')
